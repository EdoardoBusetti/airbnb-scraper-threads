# %%
import time
import numpy as np
import math
import re
import copy
import pandas as pd
from datetime import datetime, timedelta
from models import CalendarDayState, AirBnbRoomCalendarDay
import logging

from my_webdriver import driver_setup
from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait


MAX_WAIT_FOR_TRANSLATION_ON_POPUP_SEC = 5
MAX_WAIT_FOR_COOKIES_POPUP_SEC = 5
NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK = 6
MONTHS_PRESENT_IN_ONE_ELEMENT = 4
TIME_SLEEP_AFTER_CAL_NEXT_CLICK_SEC = 0.2
NUMBER_CAL_FETCHES_NEEDED = math.ceil(
    NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK / MONTHS_PRESENT_IN_ONE_ELEMENT
)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(name)s - %(message)s', 
    datefmt='%Y-%m-%d %H:%M:%S',  # Customize the time format (optional)
    force=True,
)
logger = logging.getLogger(__name__)


from  selenium_airbnb_calendar_scraper import close_translation_popup_if_exists,close_cookie_banner_if_exists,parse_date,get_calendar_table_from_driver,is_day_disabled,clear_dates,get_two_visible_tables,parse_from_day_button_aria_label_to_state, first_day_of_month,get_all_cells_from_table, parse_pricing_from_pricing_form,  from_pricing_elements_to_pricing_dict, calculate_mean, get_two_visible_tables_with_retry, next_month, get_state_and_num_min_nights_of_given_date, get_smallest_stay_interval_and_pricing_dict, enrich_calendar_days_details_if_data_is_available, generate_airbnb_calendar_day_list

# %%
driver = driver_setup(settings={"headless": False})
ROOM_ID = 14132224
ROOM_URL_FOR_TEST=  f"https://www.airbnb.com/rooms/{ROOM_ID}?adults=2" # "https://www.airbnb.com/rooms/634438216271572667?adults=2"
NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK = 6

logger.info("[%s] getting room", ROOM_ID)
driver.get(ROOM_URL_FOR_TEST)
logger.info("[%s] room gotten", ROOM_ID)
close_translation_popup_if_exists(driver, ROOM_ID)
logger.info("[%s] close_translation_popup_if_exists over", ROOM_ID)
close_cookie_banner_if_exists(driver, ROOM_ID)
logger.info("[%s] close_cookie_banner_if_exists over", ROOM_ID)


calendar_days_details_empty_template = {'current_date_state':None,'minimum_stay_nights':None,'latest_prices_array':[],'cleaning_fee':None,'currency':None,'extra_attributes':{},'price':None}
calendar_days_details = {}
old_visible_table_one_string = None
for num_nexts_to_click in range(NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK):
    old_visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables_with_retry(driver, old_visible_table_one_string,ROOM_ID, sleep_after_retry_sec=1, max_retries=3)
    logger.info("[%s] old_visible_table_one_string: %s, first_visible_table: %s, second_visible_table: %s", ROOM_ID,old_visible_table_one_string, first_visible_table,second_visible_table)
    second_visible_table_cells = None
    first_visible_table_cells = get_all_cells_from_table(first_visible_table)
    for first_table_cell_index,first_table_cell in enumerate(first_visible_table_cells):
        date_button_aria_label = first_table_cell.get_attribute("aria-label")
        date_button_date = parse_date(date_button_aria_label.split(".", 1)[0])
        # time.sleep(10000000)
        current_date_state, num_nights = get_state_and_num_min_nights_of_given_date(date_button_aria_label,first_table_cell,first_visible_table,driver, ROOM_ID)
        logger.info("[%s] date_button_date: %s. current_date_state: %s. num_nights: %s.",ROOM_ID,date_button_date, current_date_state, num_nights)
        pricing_dict, second_visible_table_cells = get_smallest_stay_interval_and_pricing_dict(current_date_state,num_nights, date_button_date, second_visible_table, second_visible_table_cells, first_visible_table_cells, first_table_cell, first_table_cell_index, driver, ROOM_ID)
        calendar_days_details.setdefault(date_button_date, copy.deepcopy(calendar_days_details_empty_template))
        calendar_days_details[date_button_date]['current_date_state'] = current_date_state
        calendar_days_details[date_button_date]['minimum_stay_nights'] = num_nights
        calendar_days_details, pricing_dict = enrich_calendar_days_details_if_data_is_available(calendar_days_details_empty_template, current_date_state, pricing_dict, calendar_days_details, date_button_date, num_nights)

    if (num_nexts_to_click+1) < NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK:
        next_month(driver)
    time.sleep(1)
# Out:
# 2024-09-15 14:37:02 - INFO - __main__ - [14132224] getting room
# 2024-09-15 14:37:08 - INFO - __main__ - [14132224] room gotten
# 2024-09-15 14:37:08 - INFO - __main__ - [14132224] close_translation_popup_if_exists over
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] close_cookie_banner_if_exists over
# 2024-09-15 14:37:09 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-09-15 14:37:09 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 1 is for month September 2024
# 2024-09-15 14:37:09 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 2 is for month October 2024
# 2024-09-15 14:37:09 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] old_visible_table_one_string: September 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="54ed57bd8d604c34d30839aea0e219a8", element="f.0EB022432CB4D9F685681830E423A576.d.52F3B13E11C7850DB5CA55A02F1D6B8F.e.40")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="54ed57bd8d604c34d30839aea0e219a8", element="f.0EB022432CB4D9F685681830E423A576.d.52F3B13E11C7850DB5CA55A02F1D6B8F.e.43")>
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-01. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-02. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-03. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-04. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-05. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-06. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-07. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-08. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-09. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-10. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-11. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-12. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-13. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-14. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-15. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-16. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-17. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-18. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-19. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-20. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-21. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-22. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-23. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-24. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-25. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-26. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:09 - INFO - __main__ - [14132224] date_button_date: 2024-09-27. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:10 - INFO - __main__ - [14132224] date_button_date: 2024-09-28. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:10 - INFO - __main__ - [14132224] date_button_date: 2024-09-29. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:10 - INFO - __main__ - [14132224] date_button_date: 2024-09-30. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-09-15 14:37:11 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 1 is for month October 2024
# 2024-09-15 14:37:11 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 2 is for month November 2024
# 2024-09-15 14:37:11 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] old_visible_table_one_string: October 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="54ed57bd8d604c34d30839aea0e219a8", element="f.0EB022432CB4D9F685681830E423A576.d.52F3B13E11C7850DB5CA55A02F1D6B8F.e.43")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="54ed57bd8d604c34d30839aea0e219a8", element="f.0EB022432CB4D9F685681830E423A576.d.52F3B13E11C7850DB5CA55A02F1D6B8F.e.109")>
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-01. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-02. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-03. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-04. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-05. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-06. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-07. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-08. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-09. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-10. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-11. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-12. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-13. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-14. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-15. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-16. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-17. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-18. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-19. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:11 - INFO - __main__ - [14132224] date_button_date: 2024-10-20. current_date_state: AVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £18
# 2024-09-15 14:37:12 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£18'}]
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-21. current_date_state: CHECKOUT_ONLY. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-22. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-23. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-24. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-25. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-26. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-27. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-28. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-29. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-30. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:12 - INFO - __main__ - [14132224] date_button_date: 2024-10-31. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:37:13 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-09-15 14:37:13 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 1 is for month November 2024
# 2024-09-15 14:37:13 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 2 is for month December 2024
# 2024-09-15 14:37:13 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-09-15 14:37:13 - INFO - __main__ - [14132224] old_visible_table_one_string: November 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="54ed57bd8d604c34d30839aea0e219a8", element="f.0EB022432CB4D9F685681830E423A576.d.52F3B13E11C7850DB5CA55A02F1D6B8F.e.109")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="54ed57bd8d604c34d30839aea0e219a8", element="f.0EB022432CB4D9F685681830E423A576.d.52F3B13E11C7850DB5CA55A02F1D6B8F.e.169")>
# 2024-09-15 14:37:14 - INFO - __main__ - [14132224] date_button_date: 2024-11-01. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14
current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:38 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:38 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:38 - INFO - __main__ - [14132224] date_button_date: 2025-02-08. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:40 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:40 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:41 - INFO - __main__ - [14132224] date_button_date: 2025-02-09. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:43 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:43 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:43 - INFO - __main__ - [14132224] date_button_date: 2025-02-10. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:45 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:45 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:46 - INFO - __main__ - [14132224] date_button_date: 2025-02-11. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:48 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:48 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:48 - INFO - __main__ - [14132224] date_button_date: 2025-02-12. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:50 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:50 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:50 - INFO - __main__ - [14132224] date_button_date: 2025-02-13. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:52 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:52 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:52 - INFO - __main__ - [14132224] date_button_date: 2025-02-14. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:54 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:54 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:54 - INFO - __main__ - [14132224] date_button_date: 2025-02-15. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:56 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:56 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:57 - INFO - __main__ - [14132224] date_button_date: 2025-02-16. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:40:59 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:40:59 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:40:59 - INFO - __main__ - [14132224] date_button_date: 2025-02-17. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:41:01 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:41:01 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:41:01 - INFO - __main__ - [14132224] date_button_date: 2025-02-18. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:41:03 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:41:03 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:41:03 - INFO - __main__ - [14132224] date_button_date: 2025-02-19. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:41:05 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:41:05 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:41:05 - INFO - __main__ - [14132224] date_button_date: 2025-02-20. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:41:08 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:41:08 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:41:08 - INFO - __main__ - [14132224] date_button_date: 2025-02-21. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:41:10 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:41:10 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:41:10 - INFO - __main__ - [14132224] date_button_date: 2025-02-22. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:41:12 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:41:12 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:41:12 - INFO - __main__ - [14132224] date_button_date: 2025-02-23. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-15 14:41:14 - WARNING - selenium_airbnb_calendar_scraper - We did not find any matching pattern in the input string: Airbnb service fee
# Show price breakdown
# £31
# 2024-09-15 14:41:14 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 72, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 25, 'currency': '£', 'extra': ''}, {'description': 'other', 'amount': None, 'currency': None, 'extra': 'Airbnb service fee\nShow price breakdown\n£31'}]
# 2024-09-15 14:41:14 - INFO - __main__ - [14132224] date_button_date: 2025-02-24. current_date_state: AVAILABLE_NO_CHECKOUT_DATE. num_nights: 2.
# 2024-09-15 14:41:14 - INFO - __main__ - [14132224] date_button_date: 2025-02-25. current_date_state: CHECKOUT_ONLY. num_nights: 1.
# 2024-09-15 14:41:14 - INFO - __main__ - [14132224] date_button_date: 2025-02-26. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:41:14 - INFO - __main__ - [14132224] date_button_date: 2025-02-27. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-09-15 14:41:14 - INFO - __main__ - [14132224] date_button_date: 2025-02-28. current_date_state: UNAVAILABLE. num_nights: 1.

# %%
calendar_days_details_models = generate_airbnb_calendar_day_list(calendar_days_details,ROOM_ID)

# %%
[ i for i in calendar_days_details_models if i.currency][0].price
# Out:
# 72.0

# %%
from models import Base, db_url, save_or_update_airbnb_date
import sqlalchemy
from sqlalchemy.orm import Session
engine = sqlalchemy.create_engine(
    db_url, echo=False
)  # We have also specified a parameter create_engine.echo, which will instruct the Engine to log all of the SQL it emits to a Python logger that will write to standard out.
Base.metadata.create_all(engine)

session = Session(engine)
for i in calendar_days_details_models:
    save_or_update_airbnb_date(session=session, new_instance=i)

# %%
len(calendar_days_details_models)
# Out:
# 181
