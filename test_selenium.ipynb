# %%
import time
import numpy as np
import math
import re
import copy
import pandas as pd
from datetime import datetime, timedelta
from models import CalendarDayState, AirBnbRoomCalendarDay
import logging
from my_webdriver import driver_setup
from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait


MAX_WAIT_FOR_TRANSLATION_ON_POPUP_SEC = 5
NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK = 6
MONTHS_PRESENT_IN_ONE_ELEMENT = 4
TIME_SLEEP_AFTER_CAL_NEXT_CLICK_SEC = 0.2
NUMBER_CAL_FETCHES_NEEDED = math.ceil(
    NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK / MONTHS_PRESENT_IN_ONE_ELEMENT
)
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


def close_translation_popup_if_exists(driver):
    try:
        # Wait for the element to be present
        element = WebDriverWait(driver, MAX_WAIT_FOR_TRANSLATION_ON_POPUP_SEC).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, ".p1psejvv.atm_9s_1bgihbq.dir.dir-ltr")
            )
        )
        active_element = driver.switch_to.active_element
        active_element.send_keys(Keys.ESCAPE)
    except:
        print("No 'Transaction on' form was found")


def open_the_calendar_form(driver):
    try:
        button = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable(
                (By.CSS_SELECTOR, "._16l1qv1")
            )  # check-in date form button
        )
        # Click the button
        button.click()
        print("'Transaction on' esc button clicked successfully.")
    except Exception as e:
        # If the button is not found or another exception occurs, print an error message
        print(f"Exception occurred: {e}")


def parse_date(date_string):
    # Define the format of the input string
    # %d: Day of the month as a zero-padded decimal number.
    # %A: Full weekday name.
    # %B: Full month name.
    # %Y: Year with century as a decimal number.
    date_format = "%d, %A, %B %Y"
    if "Today" in date_string:
        date_string = date_string.rsplit(",", 1)[0]
    # Parse the date string into a datetime object
    parsed_date = datetime.strptime(date_string, date_format).date()

    return parsed_date


def get_calendar_table_from_driver(driver):
    tables = WebDriverWait(driver, 10).until(
        EC.presence_of_all_elements_located((By.CSS_SELECTOR, "._cvkwaj"))
    )
    all_tables_data = []  # Initialize list to store all data

    # Iterate through each table
    for table in tables:
        # Extract rows from the current table
        rows = table.find_elements(By.TAG_NAME, "tr")

        # Initialize list to store data for the current table

        # Iterate through rows and extract cell data
        for row in rows:
            cells = row.find_elements(By.TAG_NAME, "td")
            for cell in cells:
                # Extract desired attributes
                cell_data = {
                    "aria-disabled": cell.get_attribute("aria-disabled"),
                    "aria-label": cell.get_attribute("aria-label"),
                    # "class": cell.get_attribute("class")
                }
                all_tables_data.append(cell_data)
    return all_tables_data


def is_day_disabled(day_disabled):
    if type(day_disabled) == bool:
        return day_disabled
    else:
        if day_disabled.lower() == "true":
            return True
        else:
            return False


def get_dates_availability(driver):
    t0 = datetime.now()
    try:
        all_tables_data = get_calendar_table_from_driver(driver)
    except Exception as e:
        print(e)
        time.sleep(2)
        print("sleeping 2s and trying Again...")
        all_tables_data = get_calendar_table_from_driver(driver)

    all_tables_data_clean = []
    for cell_attributes in all_tables_data:
        if cell_attributes.get(
            "aria-disabled"
        ):  # only if this is true, then it is a calendar day
            date_string, reason_string = cell_attributes["aria-label"].split(".", 1)
            all_tables_data_clean.append(
                {
                    "day_disabled": is_day_disabled(cell_attributes["aria-disabled"]),
                    "day_label":cell_attributes["aria-label"],
                    "date": parse_date(date_string),
                    "reason_string": reason_string.strip(),
                }
            )

    t1 = datetime.now()
    logger.info(
        "found %s elements. time for calendar fetch %s. last elem %s",
        len(all_tables_data_clean),
        t1 - t0,
        all_tables_data_clean[-1]["date"],
    )
    return all_tables_data_clean

def clear_dates(driver):
    clear_dates_button = driver.find_element(By.XPATH, "//button[text()='Clear dates']")
    clear_dates_button.click()


def get_all_dates_availability(
    driver,
    number_cal_fetches_needed,
    months_present_in_one_element,
    time_sleep_after_cal_next_click_sec,
):
    all_table_data_clean_all_months = []
    for cal_fetch_iter_counter in range(number_cal_fetches_needed):
        all_tables_data_clean = get_dates_availability(driver)
        all_table_data_clean_all_months += all_tables_data_clean
        if (cal_fetch_iter_counter + 1) < number_cal_fetches_needed:
            for next_button_press_iter_count in range(months_present_in_one_element):
                next_button = driver.find_element(By.CLASS_NAME, "_qz9x4fc")
                logger.info(
                    "clicking next button. cal iteration %s. button click %s",
                    cal_fetch_iter_counter,
                    next_button_press_iter_count,
                )
                next_button.click()
                if (next_button_press_iter_count + 1) < months_present_in_one_element:
                    time.sleep(time_sleep_after_cal_next_click_sec)
            time.sleep(1)
    return all_table_data_clean_all_months


def get_two_visible_tables(driver,old_visible_table_one_string):
    visible_table_names = []
    visible_table_index = 0
    tables_divs = WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "._ytfarf")))
    first_visible_table = None
    second_visible_table = None
    visible_table_one_string = None
    for table_div in tables_divs:
        month_string = table_div.find_element(By.CLASS_NAME, '_1qlawxx').find_element(By.TAG_NAME, 'h3').text
        if month_string == old_visible_table_one_string:
            logger.info("found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made")
            month_string = None
        visible_table_names.append(month_string)
        if not month_string:
            logger.info("table is not visible. Will will go to next one")
        else:
            visible_table_index+=1
            logger.info("visible table number %s is for month %s",visible_table_index, month_string)
            table = table_div.find_element(By.TAG_NAME, 'table')
            if visible_table_index ==1:
                first_visible_table = table
                visible_table_one_string = month_string
            elif visible_table_index ==2:
                second_visible_table = table
            else:
                raise ValueError(f"There are more than 2 visible tables: {visible_table_names}")
    return visible_table_one_string, first_visible_table, second_visible_table

def parse_from_day_button_aria_label_to_state(date_button_aria_label):
    patterns = {
        CalendarDayState.UNAVAILABLE: re.compile(r'\bunavailable\b', re.IGNORECASE),
        CalendarDayState.AVAILABLE: re.compile(r'\bavailable\.\s*there\s+is\s+a\s+(\d+)\s+night\s+minimum', re.IGNORECASE),
        CalendarDayState.AVAILABLE_NO_CHECKOUT_DATE: re.compile(r'\bavailable,\s*but\s*has\s*no\s*eligible\s*checkout\s*date.*?(\d+)\s+night\s*stay', re.IGNORECASE),
        CalendarDayState.CHECKOUT_ONLY: re.compile(r'\bthis\s+day\s+is\s+only\s+available\s+for\s+checkout\b', re.IGNORECASE),
        CalendarDayState.UNAVAILABLE_DUE_TO_PAST_DATE: re.compile(r'\bpast\s+dates?\s+can’t\s+be\s+selected\b', re.IGNORECASE),
    }
    
    for state, pattern in patterns.items():
        match = pattern.search(date_button_aria_label)
        if match:
            num_nights = int(match.group(1)) if match.lastindex else None
            return state, num_nights
    
    logger.error(f"Input string does not match any known patterns: {date_button_aria_label}")
    raise ValueError(f"Input string does not match any known patterns: {date_button_aria_label}")

def first_day_of_month(date):
    # Create a new datetime object with the first day of the month
    return datetime(date.year, date.month, 1).date()

def get_all_cells_from_table(table):
    all_cells = []
    for row in table.find_elements(By.TAG_NAME, "tr"):
        cells = row.find_elements(By.TAG_NAME, "td")
        all_cells += [cell for cell in cells if cell.get_attribute("aria-label")]
    return all_cells

import re


def parse_pricing_from_pricing_form(input_string,num_nights):
    # Define extended currency symbols
    currency_symbols = r"[\€\$\£\¥\₹\₩\₽\₺\₴\฿\₵\₦\₫\₪\₱\₲\₡\₣\₭\₮]"

    # Initialize default return values
    result = {'description': 'other', 'amount': None, 'currency': None, 'extra': input_string.strip()}

    # Convert to lowercase for case-insensitive matching
    lower_input = input_string.lower()

    # Check for early_bird_discount pattern
    if (( 'early' in lower_input) and ('bird' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'early_bird_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result
        
    # Check for last_minute_discount pattern
    if (( 'last' in lower_input) and ('minute' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'last_minute_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for accommodation_nightly pattern
    if 'accommodation' in lower_input:
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'accommodation_nightly',
                'amount': amount/num_nights,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for night_price pattern
    if 'night' in lower_input:
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'night_price',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result
    
    # Check for weekly_discount pattern
    if (('weekly' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'weekly_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for monthly_discount pattern
    if (('monthly' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'monthly_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for cleaning_fee pattern
    if 'cleaning' in lower_input:
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'cleaning_fee',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # If no match, return 'other'
    logger.warning("We did not find any matching pattern in the input string: %s",input_string)
    return result

def from_pricing_elements_to_pricing_dict(pricing_parsed_elements):
    pricing_dictionary_clean = {}
    others_count = 0
    currencies_set = set()
    for pricing_element in pricing_parsed_elements:
        if pricing_element['description'] in {'night_price','accommodation_nightly'}:
            pricing_dictionary_clean['price'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'early_bird_discount'}:
            pricing_dictionary_clean['early_bird_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'weekly_discount'}:
            pricing_dictionary_clean['weekly_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'monthly_discount'}:
            pricing_dictionary_clean['monthly_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'last_minute_discount'}:
            pricing_dictionary_clean['last_minute_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'cleaning_fee'}:
            pricing_dictionary_clean['cleaning_fee'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] == 'other':
            others_count_str = '' if others_count==0 else str(others_count)
            pricing_dictionary_clean[others_count_str] = pricing_element['extra']
        else:
            raise ValueError(f"no specification found for pricing_element['description'] == {pricing_element['description']}")
        assert len(currencies_set) == 1, f"No currency found or multiple ccys found: {currencies_set}"
    pricing_dictionary_clean['currency'] = list(currencies_set)[0]
        
    return pricing_dictionary_clean

def calculate_mean(prices):
    # Convert list to numpy array for handling nan values
    prices_array = np.array(prices, dtype=float)
    
    # Filter out None and nan values
    valid_prices = prices_array[~np.isnan(prices_array)]
    
    # Check if there are valid prices
    if len(valid_prices) == 0:
        return None
    
    # Return the mean of valid prices
    return np.mean(valid_prices)

def get_two_visible_tables_with_retry(driver,old_visible_table_one_string, sleep_after_retry_sec=1, max_retries=3):
    """
    Retries to get two visible tables with sleep in between.
    """
    retries = 0
    while retries < max_retries:
        visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables(driver,old_visible_table_one_string)
        
        if first_visible_table and second_visible_table:
            return visible_table_one_string, first_visible_table, second_visible_table
        
        logger.info("Not found visible tables on iteration %d", retries + 1)
        time.sleep(sleep_after_retry_sec)
        retries += 1
    
    # Final attempt
    visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables(driver,old_visible_table_one_string)
    return visible_table_one_string, first_visible_table, second_visible_table

def next_month(driver):
    next_month_button = driver.find_element(By.XPATH, '//button[contains(@aria-label, "forward to switch")]')
    next_month_button.click()

# %%
driver = driver_setup(settings={"headless": False})
ROOM_ID = 34281543
ROOM_URL_FOR_TEST=  f"https://www.airbnb.com/rooms/{ROOM_ID}?adults=2" # "https://www.airbnb.com/rooms/634438216271572667?adults=2"
driver.get(ROOM_URL_FOR_TEST)
NUMBER_MONTHS_TO_CHECK = 6


close_translation_popup_if_exists(driver)
# open_the_calendar_form(driver) # not needed as there is a table with dates in the main page, without even clicking on the calendar popup

# %%
calendar_days_details_empty_template = {'state':None,'minimum_stay_nights':None,'latest_prices_array':[],'cleaning_fee':None,'currency':None,'extra_attributes':{},'price':None}
calendar_days_details = {}
old_visible_table_one_string = None
for num_nexts_to_click in range(NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK):
    old_visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables_with_retry(driver, old_visible_table_one_string, sleep_after_retry_sec=1, max_retries=3)
    second_visible_table_cells = None
    first_visible_table_cells = get_all_cells_from_table(first_visible_table)
    for first_table_cell_index,first_table_cell in enumerate(first_visible_table_cells):
        # if first_table_cell_index < 20: continue ### DEBUG REMOVE
        date_button_aria_label = first_table_cell.get_attribute("aria-label")
        # if 'past dates' in date_button_aria_label.lower():continue # We do not process past dates
        date_string, reason_string = date_button_aria_label.split(".", 1)
        date_button_date = parse_date(date_string)
        is_check_in_date = "Select as check-in date" in date_button_aria_label
        if is_check_in_date:
            first_table_cell.click()
            current_date_button = first_visible_table.find_element(By.XPATH, ".//td[contains(@aria-label, 'Selected check-in date')]")
            clear_dates(driver)
            current_date_button_aria_label = current_date_button.get_attribute("aria-label")
            aria_label_to_use_for_check = current_date_button_aria_label
        else:
            aria_label_to_use_for_check = date_button_aria_label
        state, num_nights = parse_from_day_button_aria_label_to_state(aria_label_to_use_for_check)
            
        logger.info("%s %s. is_check_in_date: %s. label: %s",date_string, state, is_check_in_date, aria_label_to_use_for_check)
        if (num_nights and state == CalendarDayState.AVAILABLE):
            min_checkout_date = date_button_date + timedelta(days=num_nights)
            if (min_checkout_date.month != date_button_date.month):
                new_month_checkout_date_index=(min_checkout_date - first_day_of_month(min_checkout_date)).days
                logger.info(f"{date_button_date} checkout will be M+1 : {min_checkout_date}. new_month_checkout_date_index: {new_month_checkout_date_index}")
                if not second_visible_table_cells:
                    second_visible_table_cells = get_all_cells_from_table(second_visible_table)
                    logger.info(f"len(second_visible_table_cells): {len(second_visible_table_cells)}")
                
                checkout_date_button_to_click = second_visible_table_cells[new_month_checkout_date_index]
                logger.info(f'checkout_date_button_to_click.get_attribute("aria-label"): {checkout_date_button_to_click.get_attribute("aria-label")}')
                    
            else:
                checkout_date_button_to_click = first_visible_table_cells[first_table_cell_index + num_nights]
            
            ### click on the check-in and check-out dates. Then get pricing info
            first_table_cell.click()
            checkout_date_button_to_click.click()
            pricing_form_divs = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CSS_SELECTOR, "._1n7cvm7")))
            pricing_elements = pricing_form_divs.find_elements(By.CLASS_NAME, '_14omvfj')
            pricing_parsed_elements = []
            for pricing_element in pricing_elements:
                pricing_parsed_elements.append(parse_pricing_from_pricing_form(pricing_element.text,num_nights=num_nights))
            logger.info("pricing_parsed_elements: %s", pricing_parsed_elements)
            assert len([i for i in pricing_parsed_elements if i['description'] in {'night_price','accommodation_nightly'}]) ==1, "There is no night price for this listing????"
            clear_dates(driver)
            pricing_dict = from_pricing_elements_to_pricing_dict(pricing_parsed_elements)
            
        else:
            pass # DATE NOT AVIALABEL
                
        if date_button_date not in calendar_days_details:
            calendar_days_details[date_button_date] = copy.deepcopy(calendar_days_details_empty_template)
        calendar_days_details[date_button_date]['state'] = state
        calendar_days_details[date_button_date]['minimum_stay_nights'] = num_nights
        if state in {CalendarDayState.AVAILABLE,CalendarDayState}:
            current_price = pricing_dict.get('price')
            
            pricing_dict.pop('price',None)
            calendar_days_details[date_button_date]['cleaning_fee'] = pricing_dict.get('cleaning_fee')
            pricing_dict.pop('cleaning_fee',None)
            calendar_days_details[date_button_date]['currency'] = pricing_dict.get('currency')
            pricing_dict.pop('currency',None)
            calendar_days_details[date_button_date]['extra_attributes'] = pricing_dict
            for next_day_index in range(0, num_nights):
                list_to_append = [{'check_in':date_button_date,'check_out':(date_button_date + timedelta(days=num_nights)), 'price':current_price}]
                future_day_date = date_button_date+timedelta(days=next_day_index)
                if future_day_date not in calendar_days_details:
                    calendar_days_details[future_day_date] = copy.deepcopy(calendar_days_details_empty_template)
                calendar_days_details[future_day_date]['latest_prices_array'] += list_to_append
    if (num_nexts_to_click+1) < NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK:
        next_month(driver)
    time.sleep(1)
            
    
            
    # calendar_days_details[date_button_date]['price'] = calculate_mean([i['price'] for i in calendar_days_details[date_button_date]['latest_prices_array']]) DO ONLY AT THE END. ONCE YOU PROCESSED ALL DAYS YOU WANT
# Out:
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:Not found visible tables on iteration 1
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month September 2024
# INFO:__main__:visible table number 2 is for month October 2024
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:1, Sunday, September 2024 UNAVAILABLE_DUE_TO_PAST_DATE. is_check_in_date: False. label: 1, Sunday, September 2024. Past dates can’t be selected.
# INFO:__main__:2, Monday, September 2024 UNAVAILABLE_DUE_TO_PAST_DATE. is_check_in_date: False. label: 2, Monday, September 2024. Past dates can’t be selected.
# INFO:__main__:3, Tuesday, September 2024 UNAVAILABLE_DUE_TO_PAST_DATE. is_check_in_date: False. label: 3, Tuesday, September 2024. Past dates can’t be selected.
# INFO:__main__:4, Wednesday, September 2024 UNAVAILABLE_DUE_TO_PAST_DATE. is_check_in_date: False. label: 4, Wednesday, September 2024. Past dates can’t be selected.
# INFO:__main__:5, Thursday, September 2024, Today UNAVAILABLE. is_check_in_date: False. label: 5, Thursday, September 2024, Today. Unavailable
# INFO:__main__:6, Friday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 6, Friday, September 2024. Unavailable
# INFO:__main__:7, Saturday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 7, Saturday, September 2024. Unavailable
# INFO:__main__:8, Sunday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 8, Sunday, September 2024. Unavailable
# INFO:__main__:9, Monday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 9, Monday, September 2024. Unavailable
# INFO:__main__:10, Tuesday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 10, Tuesday, September 2024. Unavailable
# INFO:__main__:11, Wednesday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 11, Wednesday, September 2024. Unavailable
# INFO:__main__:12, Thursday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 12, Thursday, September 2024. Unavailable
# INFO:__main__:13, Friday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 13, Friday, September 2024. Unavailable
# INFO:__main__:14, Saturday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 14, Saturday, September 2024. Unavailable
# INFO:__main__:15, Sunday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 15, Sunday, September 2024. Unavailable
# INFO:__main__:16, Monday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 16, Monday, September 2024. Unavailable
# INFO:__main__:17, Tuesday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 17, Tuesday, September 2024. Unavailable
# INFO:__main__:18, Wednesday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 18, Wednesday, September 2024. Unavailable
# INFO:__main__:19, Thursday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 19, Thursday, September 2024. Unavailable
# INFO:__main__:20, Friday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 20, Friday, September 2024. Unavailable
# INFO:__main__:21, Saturday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 21, Saturday, September 2024. Unavailable
# INFO:__main__:22, Sunday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 22, Sunday, September 2024. Unavailable
# INFO:__main__:23, Monday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 23, Monday, September 2024. Unavailable
# INFO:__main__:24, Tuesday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 24, Tuesday, September 2024. Unavailable
# INFO:__main__:25, Wednesday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 25, Wednesday, September 2024. Unavailable
# INFO:__main__:26, Thursday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 26, Thursday, September 2024. Unavailable
# INFO:__main__:27, Friday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 27, Friday, September 2024. Unavailable
# INFO:__main__:28, Saturday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 28, Saturday, September 2024. Unavailable
# INFO:__main__:29, Sunday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 29, Sunday, September 2024. Unavailable
# INFO:__main__:30, Monday, September 2024 UNAVAILABLE. is_check_in_date: False. label: 30, Monday, September 2024. Unavailable
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month October 2024
# INFO:__main__:visible table number 2 is for month November 2024
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:1, Tuesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 1, Tuesday, October 2024. Unavailable
# INFO:__main__:2, Wednesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 2, Wednesday, October 2024. Unavailable
# INFO:__main__:3, Thursday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 3, Thursday, October 2024. Unavailable
# INFO:__main__:4, Friday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 4, Friday, October 2024. Unavailable
# INFO:__main__:5, Saturday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 5, Saturday, October 2024. Unavailable
# INFO:__main__:6, Sunday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 6, Sunday, October 2024. Unavailable
# INFO:__main__:7, Monday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 7, Monday, October 2024. Unavailable
# INFO:__main__:8, Tuesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 8, Tuesday, October 2024. Unavailable
# INFO:__main__:9, Wednesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 9, Wednesday, October 2024. Unavailable
# INFO:__main__:10, Thursday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 10, Thursday, October 2024. Unavailable
# INFO:__main__:11, Friday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 11, Friday, October 2024. Unavailable
# INFO:__main__:12, Saturday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 12, Saturday, October 2024. Unavailable
# INFO:__main__:13, Sunday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 13, Sunday, October 2024. Unavailable
# INFO:__main__:14, Monday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 14, Monday, October 2024. Unavailable
# INFO:__main__:15, Tuesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 15, Tuesday, October 2024. Unavailable
# INFO:__main__:16, Wednesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 16, Wednesday, October 2024. Unavailable
# INFO:__main__:17, Thursday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 17, Thursday, October 2024. Unavailable
# INFO:__main__:18, Friday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 18, Friday, October 2024. Unavailable
# INFO:__main__:19, Saturday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 19, Saturday, October 2024. Unavailable
# INFO:__main__:20, Sunday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 20, Sunday, October 2024. Unavailable
# INFO:__main__:21, Monday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 21, Monday, October 2024. Unavailable
# INFO:__main__:22, Tuesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 22, Tuesday, October 2024. Unavailable
# INFO:__main__:23, Wednesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 23, Wednesday, October 2024. Unavailable
# INFO:__main__:24, Thursday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 24, Thursday, October 2024. Unavailable
# INFO:__main__:25, Friday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 25, Friday, October 2024. Unavailable
# INFO:__main__:26, Saturday, October 2024 AVAILABLE. is_check_in_date: True. label: 26, Saturday, October 2024. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 159, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:27, Sunday, October 2024 AVAILABLE_NO_CHECKOUT_DATE. is_check_in_date: False. label: 27, Sunday, October 2024. Available, but has no eligible checkout date, due to the 2 night stay requirement.
# INFO:__main__:28, Monday, October 2024 CHECKOUT_ONLY. is_check_in_date: False. label: 28, Monday, October 2024. This day is only available for checkout.
# INFO:__main__:29, Tuesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 29, Tuesday, October 2024. Unavailable
# INFO:__main__:30, Wednesday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 30, Wednesday, October 2024. Unavailable
# INFO:__main__:31, Thursday, October 2024 UNAVAILABLE. is_check_in_date: False. label: 31, Thursday, October 2024. Unavailable
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month November 2024
# INFO:__main__:visible table number 2 is for month December 2024
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:1, Friday, November 2024 UNAVAILABLE. is_check_in_date: False. label: 1, Friday, November 2024. Unavailable
# INFO:__main__:2, Saturday, November 2024 UNAVAILABLE. is_check_in_date: False. label: 2, Saturday, November 2024. Unavailable
# INFO:__main__:3, Sunday, November 2024 UNAVAILABLE. is_check_in_date: False. label: 3, Sunday, November 2024. Unavailable
# INFO:__main__:4, Monday, November 2024 AVAILABLE. is_check_in_date: True. label: 4, Monday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:5, Tuesday, November 2024 AVAILABLE. is_check_in_date: True. label: 5, Tuesday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:6, Wednesday, November 2024 AVAILABLE. is_check_in_date: True. label: 6, Wednesday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:7, Thursday, November 2024 AVAILABLE. is_check_in_date: True. label: 7, Thursday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:8, Friday, November 2024 AVAILABLE. is_check_in_date: True. label: 8, Friday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:9, Saturday, November 2024 AVAILABLE. is_check_in_date: True. label: 9, Saturday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:10, Sunday, November 2024 AVAILABLE. is_check_in_date: True. label: 10, Sunday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:11, Monday, November 2024 AVAILABLE. is_check_in_date: True. label: 11, Monday, November 2024. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:12, Tuesday, November 2024 AVAILABLE. is_check_in_date: True. label: 12, Tuesday, November 2024. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:13, Wednesday, November 2024 AVAILABLE. is_check_in_date: True. label: 13, Wednesday, November 2024. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:14, Thursday, November 2024 AVAILABLE. is_check_in_date: True. label: 14, Thursday, November 2024. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:15, Friday, November 2024 AVAILABLE. is_check_in_date: True. label: 15, Friday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:16, Saturday, November 2024 AVAILABLE. is_check_in_date: True. label: 16, Saturday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:17, Sunday, November 2024 AVAILABLE. is_check_in_date: True. label: 17, Sunday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:18, Monday, November 2024 AVAILABLE. is_check_in_date: True. label: 18, Monday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:19, Tuesday, November 2024 AVAILABLE. is_check_in_date: True. label: 19, Tuesday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:20, Wednesday, November 2024 AVAILABLE. is_check_in_date: True. label: 20, Wednesday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:21, Thursday, November 2024 AVAILABLE. is_check_in_date: True. label: 21, Thursday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:22, Friday, November 2024 AVAILABLE. is_check_in_date: True. label: 22, Friday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:23, Saturday, November 2024 AVAILABLE. is_check_in_date: True. label: 23, Saturday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:24, Sunday, November 2024 AVAILABLE. is_check_in_date: True. label: 24, Sunday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:25, Monday, November 2024 AVAILABLE. is_check_in_date: True. label: 25, Monday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:26, Tuesday, November 2024 AVAILABLE. is_check_in_date: True. label: 26, Tuesday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:27, Wednesday, November 2024 AVAILABLE. is_check_in_date: True. label: 27, Wednesday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:28, Thursday, November 2024 AVAILABLE. is_check_in_date: True. label: 28, Thursday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:2024-11-28 checkout will be M+1 : 2024-12-01. new_month_checkout_date_index: 0
# INFO:__main__:len(second_visible_table_cells): 31
# INFO:__main__:checkout_date_button_to_click.get_attribute("aria-label"): 1, Sunday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:29, Friday, November 2024 AVAILABLE. is_check_in_date: True. label: 29, Friday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:2024-11-29 checkout will be M+1 : 2024-12-02. new_month_checkout_date_index: 1
# INFO:__main__:checkout_date_button_to_click.get_attribute("aria-label"): 2, Monday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:30, Saturday, November 2024 AVAILABLE. is_check_in_date: True. label: 30, Saturday, November 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:2024-11-30 checkout will be M+1 : 2024-12-03. new_month_checkout_date_index: 2
# INFO:__main__:checkout_date_button_to_click.get_attribute("aria-label"): 3, Tuesday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month December 2024
# INFO:__main__:visible table number 2 is for month January 2025
# INFO:__main__:1, Sunday, December 2024 AVAILABLE. is_check_in_date: True. label: 1, Sunday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:2, Monday, December 2024 AVAILABLE. is_check_in_date: True. label: 2, Monday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:3, Tuesday, December 2024 AVAILABLE. is_check_in_date: True. label: 3, Tuesday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:4, Wednesday, December 2024 AVAILABLE. is_check_in_date: True. label: 4, Wednesday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 152, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:5, Thursday, December 2024 AVAILABLE. is_check_in_date: True. label: 5, Thursday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 166, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:6, Friday, December 2024 AVAILABLE. is_check_in_date: True. label: 6, Friday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 179, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:7, Saturday, December 2024 AVAILABLE. is_check_in_date: True. label: 7, Saturday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 166, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:8, Sunday, December 2024 AVAILABLE. is_check_in_date: True. label: 8, Sunday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 152, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:9, Monday, December 2024 AVAILABLE_NO_CHECKOUT_DATE. is_check_in_date: False. label: 9, Monday, December 2024. Available, but has no eligible checkout date, due to the 3 night stay requirement.
# INFO:__main__:10, Tuesday, December 2024 AVAILABLE_NO_CHECKOUT_DATE. is_check_in_date: False. label: 10, Tuesday, December 2024. Available, but has no eligible checkout date, due to the 3 night stay requirement.
# INFO:__main__:11, Wednesday, December 2024 CHECKOUT_ONLY. is_check_in_date: False. label: 11, Wednesday, December 2024. This day is only available for checkout.
# INFO:__main__:12, Thursday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 12, Thursday, December 2024. Unavailable
# INFO:__main__:13, Friday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 13, Friday, December 2024. Unavailable
# INFO:__main__:14, Saturday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 14, Saturday, December 2024. Unavailable
# INFO:__main__:15, Sunday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 15, Sunday, December 2024. Unavailable
# INFO:__main__:16, Monday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 16, Monday, December 2024. Unavailable
# INFO:__main__:17, Tuesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 17, Tuesday, December 2024. Unavailable
# INFO:__main__:18, Wednesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 18, Wednesday, December 2024. Unavailable
# INFO:__main__:19, Thursday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 19, Thursday, December 2024. Unavailable
# INFO:__main__:20, Friday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 20, Friday, December 2024. Unavailable
# INFO:__main__:21, Saturday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 21, Saturday, December 2024. Unavailable
# INFO:__main__:22, Sunday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 22, Sunday, December 2024. Unavailable
# INFO:__main__:23, Monday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 23, Monday, December 2024. Unavailable
# INFO:__main__:24, Tuesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 24, Tuesday, December 2024. Unavailable
# INFO:__main__:25, Wednesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 25, Wednesday, December 2024. Unavailable
# INFO:__main__:26, Thursday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 26, Thursday, December 2024. Unavailable
# INFO:__main__:27, Friday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 27, Friday, December 2024. Unavailable
# INFO:__main__:28, Saturday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 28, Saturday, December 2024. Unavailable
# INFO:__main__:29, Sunday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 29, Sunday, December 2024. Unavailable
# INFO:__main__:30, Monday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 30, Monday, December 2024. Unavailable
# INFO:__main__:31, Tuesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 31, Tuesday, December 2024. Unavailable
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month January 2025
# INFO:__main__:Not found visible tables on iteration 1
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month January 2025
# INFO:__main__:Not found visible tables on iteration 2
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month January 2025
# INFO:__main__:Not found visible tables on iteration 3
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month January 2025
# INFO:__main__:1, Wednesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 1, Wednesday, January 2025. Unavailable
# INFO:__main__:2, Thursday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 2, Thursday, January 2025. Unavailable
# INFO:__main__:3, Friday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 3, Friday, January 2025. Unavailable
# INFO:__main__:4, Saturday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 4, Saturday, January 2025. Unavailable
# INFO:__main__:5, Sunday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 5, Sunday, January 2025. Unavailable
# INFO:__main__:6, Monday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 6, Monday, January 2025. Unavailable
# INFO:__main__:7, Tuesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 7, Tuesday, January 2025. Unavailable
# INFO:__main__:8, Wednesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 8, Wednesday, January 2025. Unavailable
# INFO:__main__:9, Thursday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 9, Thursday, January 2025. Unavailable
# INFO:__main__:10, Friday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 10, Friday, January 2025. Unavailable
# INFO:__main__:11, Saturday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 11, Saturday, January 2025. Unavailable
# INFO:__main__:12, Sunday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 12, Sunday, January 2025. Unavailable
# INFO:__main__:13, Monday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 13, Monday, January 2025. Unavailable
# INFO:__main__:14, Tuesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 14, Tuesday, January 2025. Unavailable
# INFO:__main__:15, Wednesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 15, Wednesday, January 2025. Unavailable
# INFO:__main__:16, Thursday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 16, Thursday, January 2025. Unavailable
# INFO:__main__:17, Friday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 17, Friday, January 2025. Unavailable
# INFO:__main__:18, Saturday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 18, Saturday, January 2025. Unavailable
# INFO:__main__:19, Sunday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 19, Sunday, January 2025. Unavailable
# INFO:__main__:20, Monday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 20, Monday, January 2025. Unavailable
# INFO:__main__:21, Tuesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 21, Tuesday, January 2025. Unavailable
# INFO:__main__:22, Wednesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 22, Wednesday, January 2025. Unavailable
# INFO:__main__:23, Thursday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 23, Thursday, January 2025. Unavailable
# INFO:__main__:24, Friday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 24, Friday, January 2025. Unavailable
# INFO:__main__:25, Saturday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 25, Saturday, January 2025. Unavailable
# INFO:__main__:26, Sunday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 26, Sunday, January 2025. Unavailable
# INFO:__main__:27, Monday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 27, Monday, January 2025. Unavailable
# INFO:__main__:28, Tuesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 28, Tuesday, January 2025. Unavailable
# INFO:__main__:29, Wednesday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 29, Wednesday, January 2025. Unavailable
# INFO:__main__:30, Thursday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 30, Thursday, January 2025. Unavailable
# INFO:__main__:31, Friday, January 2025 UNAVAILABLE. is_check_in_date: False. label: 31, Friday, January 2025. Unavailable
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month December 2024
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:Not found visible tables on iteration 1
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month December 2024
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:Not found visible tables on iteration 2
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month December 2024
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:Not found visible tables on iteration 3
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:visible table number 1 is for month December 2024
# INFO:__main__:found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made
# INFO:__main__:table is not visible. Will will go to next one
# INFO:__main__:1, Sunday, December 2024 AVAILABLE. is_check_in_date: True. label: 1, Sunday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:2, Monday, December 2024 AVAILABLE. is_check_in_date: True. label: 2, Monday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:3, Tuesday, December 2024 AVAILABLE. is_check_in_date: True. label: 3, Tuesday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 139, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:4, Wednesday, December 2024 AVAILABLE. is_check_in_date: True. label: 4, Wednesday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 152, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:5, Thursday, December 2024 AVAILABLE. is_check_in_date: True. label: 5, Thursday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 166, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:6, Friday, December 2024 AVAILABLE. is_check_in_date: True. label: 6, Friday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 179, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:7, Saturday, December 2024 AVAILABLE. is_check_in_date: True. label: 7, Saturday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 166, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:8, Sunday, December 2024 AVAILABLE. is_check_in_date: True. label: 8, Sunday, December 2024. Available. There is a 3 night minimum stay requirement. Select as check-in date.
# INFO:__main__:pricing_parsed_elements: [{'description': 'night_price', 'amount': 152, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 70, 'currency': '€', 'extra': ''}]
# INFO:__main__:9, Monday, December 2024 AVAILABLE_NO_CHECKOUT_DATE. is_check_in_date: False. label: 9, Monday, December 2024. Available, but has no eligible checkout date, due to the 3 night stay requirement.
# INFO:__main__:10, Tuesday, December 2024 AVAILABLE_NO_CHECKOUT_DATE. is_check_in_date: False. label: 10, Tuesday, December 2024. Available, but has no eligible checkout date, due to the 3 night stay requirement.
# INFO:__main__:11, Wednesday, December 2024 CHECKOUT_ONLY. is_check_in_date: False. label: 11, Wednesday, December 2024. This day is only available for checkout.
# INFO:__main__:12, Thursday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 12, Thursday, December 2024. Unavailable
# INFO:__main__:13, Friday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 13, Friday, December 2024. Unavailable
# INFO:__main__:14, Saturday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 14, Saturday, December 2024. Unavailable
# INFO:__main__:15, Sunday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 15, Sunday, December 2024. Unavailable
# INFO:__main__:16, Monday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 16, Monday, December 2024. Unavailable
# INFO:__main__:17, Tuesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 17, Tuesday, December 2024. Unavailable
# INFO:__main__:18, Wednesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 18, Wednesday, December 2024. Unavailable
# INFO:__main__:19, Thursday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 19, Thursday, December 2024. Unavailable
# INFO:__main__:20, Friday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 20, Friday, December 2024. Unavailable
# INFO:__main__:21, Saturday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 21, Saturday, December 2024. Unavailable
# INFO:__main__:22, Sunday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 22, Sunday, December 2024. Unavailable
# INFO:__main__:23, Monday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 23, Monday, December 2024. Unavailable
# INFO:__main__:24, Tuesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 24, Tuesday, December 2024. Unavailable
# INFO:__main__:25, Wednesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 25, Wednesday, December 2024. Unavailable
# INFO:__main__:26, Thursday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 26, Thursday, December 2024. Unavailable
# INFO:__main__:27, Friday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 27, Friday, December 2024. Unavailable
# INFO:__main__:28, Saturday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 28, Saturday, December 2024. Unavailable
# INFO:__main__:29, Sunday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 29, Sunday, December 2024. Unavailable
# INFO:__main__:30, Monday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 30, Monday, December 2024. Unavailable
# INFO:__main__:31, Tuesday, December 2024 UNAVAILABLE. is_check_in_date: False. label: 31, Tuesday, December 2024. Unavailable

# %%
calendar_days_details_models = []
for date, date_details  in calendar_days_details.items():
    airbnb_calendar_day = AirBnbRoomCalendarDay(room_id = ROOM_ID, 
                                                calendar_day=date,
                                                state=date_details['state'],
                                                previous_state = None,
                                                minimum_stay_nights = date_details['minimum_stay_nights'],
                                                price = calculate_mean([i['price'] for i in date_details['latest_prices_array']]),
                                                latest_prices_array = date_details['latest_prices_array'],
                                                cleaning_fee = date_details['cleaning_fee'],
                                                currency = date_details['currency'],
                                                extra_attributes = date_details['extra_attributes'],
                                                )
    calendar_days_details_models.append(airbnb_calendar_day)

# %%
calendar_days_details_models
# Out:
# [<models.AirBnbRoomCalendarDay at 0x11a813750>,
#  <models.AirBnbRoomCalendarDay at 0x10a8b0a50>,
#  <models.AirBnbRoomCalendarDay at 0x11a878410>,
#  <models.AirBnbRoomCalendarDay at 0x11a68f490>,
#  <models.AirBnbRoomCalendarDay at 0x11a68f690>,
#  <models.AirBnbRoomCalendarDay at 0x11a841f90>,
#  <models.AirBnbRoomCalendarDay at 0x11a840750>,
#  <models.AirBnbRoomCalendarDay at 0x11a843590>,
#  <models.AirBnbRoomCalendarDay at 0x11a8413d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a86a710>,
#  <models.AirBnbRoomCalendarDay at 0x11a843650>,
#  <models.AirBnbRoomCalendarDay at 0x11a843410>,
#  <models.AirBnbRoomCalendarDay at 0x11a842ed0>,
#  <models.AirBnbRoomCalendarDay at 0x11a843710>,
#  <models.AirBnbRoomCalendarDay at 0x11a840490>,
#  <models.AirBnbRoomCalendarDay at 0x11a840dd0>,
#  <models.AirBnbRoomCalendarDay at 0x11a843a50>,
#  <models.AirBnbRoomCalendarDay at 0x11a841ed0>,
#  <models.AirBnbRoomCalendarDay at 0x11a843890>,
#  <models.AirBnbRoomCalendarDay at 0x11a843e90>,
#  <models.AirBnbRoomCalendarDay at 0x11a842690>,
#  <models.AirBnbRoomCalendarDay at 0x11a8418d0>,
#  <models.AirBnbRoomCalendarDay at 0x11a840510>,
#  <models.AirBnbRoomCalendarDay at 0x11a841dd0>,
#  <models.AirBnbRoomCalendarDay at 0x11a840f10>,
#  <models.AirBnbRoomCalendarDay at 0x11a840610>,
#  <models.AirBnbRoomCalendarDay at 0x11a842e90>,
#  <models.AirBnbRoomCalendarDay at 0x11a841810>,
#  <models.AirBnbRoomCalendarDay at 0x11a840150>,
#  <models.AirBnbRoomCalendarDay at 0x11a840f90>,
#  <models.AirBnbRoomCalendarDay at 0x11a843ad0>,
#  <models.AirBnbRoomCalendarDay at 0x11a8421d0>,
#  <models.AirBnbRoomCalendarDay at 0x11a843cd0>,
#  <models.AirBnbRoomCalendarDay at 0x11a840c50>,
#  <models.AirBnbRoomCalendarDay at 0x11a842010>,
#  <models.AirBnbRoomCalendarDay at 0x11a841790>,
#  <models.AirBnbRoomCalendarDay at 0x11a8429d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a701410>,
#  <models.AirBnbRoomCalendarDay at 0x10a701150>,
#  <models.AirBnbRoomCalendarDay at 0x10a701250>,
#  <models.AirBnbRoomCalendarDay at 0x10a700cd0>,
#  <models.AirBnbRoomCalendarDay at 0x10a7011d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a700110>,
#  <models.AirBnbRoomCalendarDay at 0x10a702690>,
#  <models.AirBnbRoomCalendarDay at 0x10a700990>,
#  <models.AirBnbRoomCalendarDay at 0x10a701790>,
#  <models.AirBnbRoomCalendarDay at 0x10a701490>,
#  <models.AirBnbRoomCalendarDay at 0x10a703ed0>,
#  <models.AirBnbRoomCalendarDay at 0x10a701010>,
#  <models.AirBnbRoomCalendarDay at 0x10a702590>,
#  <models.AirBnbRoomCalendarDay at 0x10a700f50>,
#  <models.AirBnbRoomCalendarDay at 0x10a703550>,
#  <models.AirBnbRoomCalendarDay at 0x11a691050>,
#  <models.AirBnbRoomCalendarDay at 0x11a690450>,
#  <models.AirBnbRoomCalendarDay at 0x11a691810>,
#  <models.AirBnbRoomCalendarDay at 0x10a6da450>,
#  <models.AirBnbRoomCalendarDay at 0x11a811e90>,
#  <models.AirBnbRoomCalendarDay at 0x11a6904d0>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f6050>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f6290>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f5a90>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f7d50>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f7250>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f6450>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f6090>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f4550>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f7ed0>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f4750>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f6ed0>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f6b50>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f4390>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f5650>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f6850>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f55d0>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f7190>,
#  <models.AirBnbRoomCalendarDay at 0x11a1f4c50>,
#  <models.AirBnbRoomCalendarDay at 0x10a84d810>,
#  <models.AirBnbRoomCalendarDay at 0x10a84ced0>,
#  <models.AirBnbRoomCalendarDay at 0x10a84d5d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a84cb50>,
#  <models.AirBnbRoomCalendarDay at 0x10a84c1d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a84da50>,
#  <models.AirBnbRoomCalendarDay at 0x10a84fa10>,
#  <models.AirBnbRoomCalendarDay at 0x10a84ca10>,
#  <models.AirBnbRoomCalendarDay at 0x10a84e5d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a84f010>,
#  <models.AirBnbRoomCalendarDay at 0x10a84d0d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a84db10>,
#  <models.AirBnbRoomCalendarDay at 0x10a84cf90>,
#  <models.AirBnbRoomCalendarDay at 0x10a84c590>,
#  <models.AirBnbRoomCalendarDay at 0x10a84cd10>,
#  <models.AirBnbRoomCalendarDay at 0x10a84cdd0>,
#  <models.AirBnbRoomCalendarDay at 0x10a84d590>,
#  <models.AirBnbRoomCalendarDay at 0x10a84c110>,
#  <models.AirBnbRoomCalendarDay at 0x10a84d790>,
#  <models.AirBnbRoomCalendarDay at 0x10a84c310>,
#  <models.AirBnbRoomCalendarDay at 0x10a84f990>,
#  <models.AirBnbRoomCalendarDay at 0x10a84d750>,
#  <models.AirBnbRoomCalendarDay at 0x10a84f710>,
#  <models.AirBnbRoomCalendarDay at 0x10a84df50>,
#  <models.AirBnbRoomCalendarDay at 0x10a6d1490>,
#  <models.AirBnbRoomCalendarDay at 0x10a6d3b50>,
#  <models.AirBnbRoomCalendarDay at 0x10a6d3d90>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ece90>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ec150>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ec7d0>,
#  <models.AirBnbRoomCalendarDay at 0x11a1edb90>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ec050>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ec610>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ee450>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ee610>,
#  <models.AirBnbRoomCalendarDay at 0x11a1ec590>,
#  <models.AirBnbRoomCalendarDay at 0x10a6f7a90>,
#  <models.AirBnbRoomCalendarDay at 0x10a6f6c10>,
#  <models.AirBnbRoomCalendarDay at 0x10a6f7d90>,
#  <models.AirBnbRoomCalendarDay at 0x10a6f7310>,
#  <models.AirBnbRoomCalendarDay at 0x10a6f5c10>,
#  <models.AirBnbRoomCalendarDay at 0x10a7340d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a736f90>,
#  <models.AirBnbRoomCalendarDay at 0x10a737b90>,
#  <models.AirBnbRoomCalendarDay at 0x10a737a90>,
#  <models.AirBnbRoomCalendarDay at 0x10a737c90>,
#  <models.AirBnbRoomCalendarDay at 0x10a736650>,
#  <models.AirBnbRoomCalendarDay at 0x10a736e50>,
#  <models.AirBnbRoomCalendarDay at 0x10a7379d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a737210>,
#  <models.AirBnbRoomCalendarDay at 0x10a737d10>,
#  <models.AirBnbRoomCalendarDay at 0x10a737890>,
#  <models.AirBnbRoomCalendarDay at 0x10a7342d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a735c50>,
#  <models.AirBnbRoomCalendarDay at 0x10a735050>,
#  <models.AirBnbRoomCalendarDay at 0x10a735610>,
#  <models.AirBnbRoomCalendarDay at 0x10a7341d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a736410>,
#  <models.AirBnbRoomCalendarDay at 0x10a734510>,
#  <models.AirBnbRoomCalendarDay at 0x10a734950>,
#  <models.AirBnbRoomCalendarDay at 0x10a734290>,
#  <models.AirBnbRoomCalendarDay at 0x10a735290>,
#  <models.AirBnbRoomCalendarDay at 0x10a7368d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a736450>,
#  <models.AirBnbRoomCalendarDay at 0x10a737390>,
#  <models.AirBnbRoomCalendarDay at 0x10a736e10>,
#  <models.AirBnbRoomCalendarDay at 0x10a736b90>,
#  <models.AirBnbRoomCalendarDay at 0x10a735850>,
#  <models.AirBnbRoomCalendarDay at 0x10a735110>,
#  <models.AirBnbRoomCalendarDay at 0x10a7351d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a734cd0>,
#  <models.AirBnbRoomCalendarDay at 0x10a734390>,
#  <models.AirBnbRoomCalendarDay at 0x10a737990>,
#  <models.AirBnbRoomCalendarDay at 0x10a735790>,
#  <models.AirBnbRoomCalendarDay at 0x10a7355d0>,
#  <models.AirBnbRoomCalendarDay at 0x10a735d50>,
#  <models.AirBnbRoomCalendarDay at 0x10a734350>]
