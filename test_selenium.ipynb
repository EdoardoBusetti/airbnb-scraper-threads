# %%
import time
import numpy as np
import math
import re
import copy
import pandas as pd
from datetime import datetime, timedelta
from models import CalendarDayState, AirBnbRoomCalendarDay
import logging

from my_webdriver import driver_setup
from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait


MAX_WAIT_FOR_TRANSLATION_ON_POPUP_SEC = 5
MAX_WAIT_FOR_COOKIES_POPUP_SEC = 5
NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK = 6
MONTHS_PRESENT_IN_ONE_ELEMENT = 4
TIME_SLEEP_AFTER_CAL_NEXT_CLICK_SEC = 0.2
NUMBER_CAL_FETCHES_NEEDED = math.ceil(
    NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK / MONTHS_PRESENT_IN_ONE_ELEMENT
)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(name)s - %(message)s', 
    datefmt='%Y-%m-%d %H:%M:%S',  # Customize the time format (optional)
    force=True,
)
logger = logging.getLogger(__name__)





def close_translation_popup_if_exists(driver, ROOM_ID):
    try:
        # Wait for the element to be present
        element = WebDriverWait(driver, MAX_WAIT_FOR_TRANSLATION_ON_POPUP_SEC).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, ".p1psejvv.atm_9s_1bgihbq.dir.dir-ltr")
            )
        )
        active_element = driver.switch_to.active_element
        active_element.send_keys(Keys.ESCAPE)
    except:
        logger.info("[%s] No 'Transaction on' form was found", ROOM_ID)

def close_cookie_banner_if_exists(driver,ROOM_ID):
    try:
        # Wait for the element to be present
        element = WebDriverWait(driver, MAX_WAIT_FOR_TRANSLATION_ON_POPUP_SEC).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, '[data-testid="main-cookies-banner-container"]')
            )
        )
        element.find_element(By.CSS_SELECTOR, '[type="button"]').click()
    except:
        logger.info("[%s] No 'cookies banner' form was found",ROOM_ID)


def open_the_calendar_form(driver):
    try:
        button = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable(
                (By.CSS_SELECTOR, "._16l1qv1")
            )  # check-in date form button
        )
        # Click the button
        button.click()
        print("'Transaction on' esc button clicked successfully.")
    except Exception as e:
        # If the button is not found or another exception occurs, print an error message
        print(f"Exception occurred: {e}")


def parse_date(date_string):
    # Define the format of the input string
    # %d: Day of the month as a zero-padded decimal number.
    # %A: Full weekday name.
    # %B: Full month name.
    # %Y: Year with century as a decimal number.
    date_format = "%d, %A, %B %Y"
    if "Today" in date_string:
        date_string = date_string.rsplit(",", 1)[0]
    # Parse the date string into a datetime object
    parsed_date = datetime.strptime(date_string, date_format).date()

    return parsed_date


def get_calendar_table_from_driver(driver):
    tables = WebDriverWait(driver, 10).until(
        EC.presence_of_all_elements_located((By.CSS_SELECTOR, "._cvkwaj"))
    )
    all_tables_data = []  # Initialize list to store all data

    # Iterate through each table
    for table in tables:
        # Extract rows from the current table
        rows = table.find_elements(By.TAG_NAME, "tr")

        # Initialize list to store data for the current table

        # Iterate through rows and extract cell data
        for row in rows:
            cells = row.find_elements(By.TAG_NAME, "td")
            for cell in cells:
                # Extract desired attributes
                cell_data = {
                    "aria-disabled": cell.get_attribute("aria-disabled"),
                    "aria-label": cell.get_attribute("aria-label"),
                    # "class": cell.get_attribute("class")
                }
                all_tables_data.append(cell_data)
    return all_tables_data


def is_day_disabled(day_disabled):
    if type(day_disabled) == bool:
        return day_disabled
    else:
        if day_disabled.lower() == "true":
            return True
        else:
            return False


def clear_dates(driver):
    clear_dates_button = driver.find_element(By.XPATH, "//button[text()='Clear dates']")
    clear_dates_button.click()

def get_two_visible_tables(driver,old_visible_table_one_string, ROOM_ID):
    visible_table_names = []
    visible_table_index = 0
    tables_divs = WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "._ytfarf")))
    first_visible_table = None
    second_visible_table = None
    visible_table_one_string = None
    for table_div in tables_divs:
        month_string = table_div.find_element(By.CLASS_NAME, '_1qlawxx').find_element(By.TAG_NAME, 'h3').text
        if month_string == old_visible_table_one_string:
            logger.info("[%s] found again as same table one the old table one. likely did not sleep enough before NEXT table button was pressed and this tables check was made",ROOM_ID)
            month_string = None
        visible_table_names.append(month_string)
        if not month_string:
            logger.info("[%s] table is not visible. Will will go to next one",ROOM_ID)
        else:
            visible_table_index+=1
            logger.info("[%s] visible table number %s is for month %s",ROOM_ID, visible_table_index, month_string)
            table = table_div.find_element(By.TAG_NAME, 'table')
            if visible_table_index ==1:
                first_visible_table = table
                visible_table_one_string = month_string
            elif visible_table_index ==2:
                second_visible_table = table
            else:
                raise ValueError("[%s] There are more than 2 visible tables: %s",ROOM_ID,visible_table_names)
    return visible_table_one_string, first_visible_table, second_visible_table

def parse_from_day_button_aria_label_to_state(date_button_aria_label):
    patterns = {
        CalendarDayState.UNAVAILABLE: re.compile(r'\bunavailable\b', re.IGNORECASE),
        CalendarDayState.AVAILABLE: re.compile(r'\bavailable\b.*?(\d+)\s*-?\s*night.*?\bminimum\b', re.IGNORECASE),
        CalendarDayState.AVAILABLE_NO_CHECKOUT_DATE: re.compile(r'\bavailable\b.*?\bno\b.*?\beligible\b.*?\bcheckout\b.*?(\d+)\s*-?\s*night\b', re.IGNORECASE),
        CalendarDayState.CHECKOUT_ONLY: re.compile(r'\bthis\s+day\s+is\s+only\s+available\s+for\s+checkout\b', re.IGNORECASE),
        CalendarDayState.UNAVAILABLE_DUE_TO_PAST_DATE: re.compile(r'\bpast\s+dates?\s+can’t\s+be\s+selected\b', re.IGNORECASE),
    }
    
    for current_date_state, pattern in patterns.items():
        match = pattern.search(date_button_aria_label)
        if match:
            num_nights = int(match.group(1)) if match.lastindex else None
            return current_date_state, num_nights
    
    logger.error(f"Input string does not match any known patterns: {date_button_aria_label}")
    raise ValueError(f"Input string does not match any known patterns: {date_button_aria_label}")

def first_day_of_month(date):
    # Create a new datetime object with the first day of the month
    return datetime(date.year, date.month, 1).date()

def get_all_cells_from_table(table):
    all_cells = []
    for row in table.find_elements(By.TAG_NAME, "tr"):
        cells = row.find_elements(By.TAG_NAME, "td")
        all_cells += [cell for cell in cells if cell.get_attribute("aria-label")]
    return all_cells

import re


def parse_pricing_from_pricing_form(input_string,num_nights):
    # Define extended currency symbols
    currency_symbols = r"[\€\$\£\¥\₹\₩\₽\₺\₴\฿\₵\₦\₫\₪\₱\₲\₡\₣\₭\₮]"

    # Initialize default return values
    result = {'description': 'other', 'amount': None, 'currency': None, 'extra': input_string.strip()}

    # Convert to lowercase for case-insensitive matching
    lower_input = input_string.lower()

    # Check for early_bird_discount pattern
    if (( 'early' in lower_input) and ('bird' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'early_bird_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result
        
    # Check for last_minute_discount pattern
    if (( 'last' in lower_input) and ('minute' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'last_minute_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for accommodation_nightly pattern
    if 'accommodation' in lower_input:
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'accommodation_nightly',
                'amount': amount/num_nights,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for night_price pattern
    if 'night' in lower_input:
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'night_price',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result
    
    # Check for weekly_discount pattern
    if (('weekly' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'weekly_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for monthly_discount pattern
    if (('monthly' in lower_input) and ('discount' in lower_input)):
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'monthly_discount',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # Check for cleaning_fee pattern
    if 'cleaning' in lower_input:
        # Extract currency symbol if present
        currency_match = re.search(currency_symbols, input_string)
        currency = currency_match.group(0) if currency_match else None
        
        # Extract amount
        amount_match = re.search(r'(\d+[\d,]*)', input_string)
        amount = int(amount_match.group(1).replace(',', '')) if amount_match else None
        
        if amount is not None:
            result.update({
                'description': 'cleaning_fee',
                'amount': amount,
                'currency': currency,
                'extra': ''
            })
            return result

    # If no match, return 'other'
    logger.warning("We did not find any matching pattern in the input string: %s",input_string)
    return result

def from_pricing_elements_to_pricing_dict(pricing_parsed_elements):
    pricing_dictionary_clean = {}
    others_count = 0
    currencies_set = set()
    for pricing_element in pricing_parsed_elements:
        if pricing_element['description'] in {'night_price','accommodation_nightly'}:
            pricing_dictionary_clean['price'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'early_bird_discount'}:
            pricing_dictionary_clean['early_bird_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'weekly_discount'}:
            pricing_dictionary_clean['weekly_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'monthly_discount'}:
            pricing_dictionary_clean['monthly_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'last_minute_discount'}:
            pricing_dictionary_clean['last_minute_discount'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] in {'cleaning_fee'}:
            pricing_dictionary_clean['cleaning_fee'] = pricing_element['amount']
            currencies_set.add(pricing_element['currency'])
        elif pricing_element['description'] == 'other':
            others_count_str = '' if others_count==0 else str(others_count)
            pricing_dictionary_clean[others_count_str] = pricing_element['extra']
        else:
            raise ValueError(f"no specification found for pricing_element['description'] == {pricing_element['description']}")
        assert len(currencies_set) == 1, f"No currency found or multiple ccys found: {currencies_set}"
    pricing_dictionary_clean['currency'] = list(currencies_set)[0]
        
    return pricing_dictionary_clean

def calculate_mean(prices):
    # Convert list to numpy array for handling nan values
    prices_array = np.array(prices, dtype=float)
    
    # Filter out None and nan values
    valid_prices = prices_array[~np.isnan(prices_array)]
    
    # Check if there are valid prices
    if len(valid_prices) == 0:
        return None
    
    # Return the mean of valid prices
    return np.mean(valid_prices)

def get_two_visible_tables_with_retry(driver,old_visible_table_one_string,ROOM_ID, sleep_after_retry_sec=1, max_retries=3):
    """
    Retries to get two visible tables with sleep in between.
    """
    retries = 0
    while retries < max_retries:
        visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables(driver,old_visible_table_one_string,ROOM_ID)
        
        if first_visible_table and second_visible_table:
            return visible_table_one_string, first_visible_table, second_visible_table
        
        logger.info("[%s] Not found visible tables on iteration %d", ROOM_ID, retries + 1)
        time.sleep(sleep_after_retry_sec)
        retries += 1
    
    # Final attempt
    visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables(driver,old_visible_table_one_string,ROOM_ID)
    return visible_table_one_string, first_visible_table, second_visible_table

def next_month(driver):
    next_month_button = driver.find_element(By.XPATH, '//button[contains(@aria-label, "forward to")]')
    next_month_button.click()
    
def get_state_and_num_min_nights_of_given_date(date_button_aria_label,first_table_cell,first_visible_table,driver,ROOM_ID,verbose=False):
    is_check_in_date = "Select as check-in date" in date_button_aria_label
    if is_check_in_date:
        first_table_cell.click()
        try:
            current_date_button = first_visible_table.find_element(By.XPATH, ".//td[contains(@aria-label, 'Selected check-in date')]")
        except:
            current_date_button = WebDriverWait(driver, 10).until(
                    EC.presence_of_element_located((By.XPATH, ".//td[contains(@aria-label, 'Selected check-in date')]"))
                )
        clear_dates(driver)
        current_date_button_aria_label = current_date_button.get_attribute("aria-label")
        aria_label_to_use_for_check = current_date_button_aria_label
    else:
        aria_label_to_use_for_check = date_button_aria_label
    if verbose:
        logger.info("[%s] is_check_in_date: %s. aria_label_to_use_for_check: %s",ROOM_ID,  is_check_in_date, aria_label_to_use_for_check)
    current_date_state, num_nights = parse_from_day_button_aria_label_to_state(aria_label_to_use_for_check)
    return current_date_state, num_nights



def get_smallest_stay_interval_and_pricing_dict(current_date_state,num_nights, date_button_date, second_visible_table, second_visible_table_cells, first_visible_table_cells, first_table_cell, first_table_cell_index, driver, ROOM_ID, verbose=True):
    if current_date_state == CalendarDayState.AVAILABLE:
        min_checkout_date = date_button_date + timedelta(days=num_nights)
        if (min_checkout_date.month != date_button_date.month):
            new_month_checkout_date_index=(min_checkout_date - first_day_of_month(min_checkout_date)).days
            if verbose:
                logger.info("[%s] %s checkout will be M+1 : %s. new_month_checkout_date_index: %s",ROOM_ID, date_button_date, min_checkout_date, new_month_checkout_date_index)
            if not second_visible_table_cells:
                second_visible_table_cells = get_all_cells_from_table(second_visible_table)
                if verbose:
                    logger.info("[%s] len(second_visible_table_cells): %s", ROOM_ID, len(second_visible_table_cells))
            
            checkout_date_button_to_click = second_visible_table_cells[new_month_checkout_date_index]
            logger.info('[%s] checkout_date_button_to_click.get_attribute("aria-label"): %s',ROOM_ID,checkout_date_button_to_click.get_attribute("aria-label"))
                
        else:
            checkout_date_button_to_click = first_visible_table_cells[first_table_cell_index + num_nights]
        
        ### click on the check-in and check-out dates. Then get pricing info
        first_table_cell.click()
        checkout_date_button_to_click.click()
        pricing_form_divs = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CSS_SELECTOR, "._1n7cvm7")))
        pricing_elements = pricing_form_divs.find_elements(By.CLASS_NAME, '_14omvfj')
        pricing_parsed_elements = []
        for pricing_element in pricing_elements:
            pricing_parsed_elements.append(parse_pricing_from_pricing_form(pricing_element.text,num_nights=num_nights))
        if verbose:
            logger.info("[%s] pricing_parsed_elements: %s",ROOM_ID, pricing_parsed_elements)
        assert len([i for i in pricing_parsed_elements if i['description'] in {'night_price','accommodation_nightly'}]) ==1, "There is no night price for this listing????"
        clear_dates(driver)
        pricing_dict = from_pricing_elements_to_pricing_dict(pricing_parsed_elements)
        
    else:
        pricing_dict = {}
        pass # DATE NOT AVIALABEL
    return pricing_dict, second_visible_table_cells

def enrich_calendar_days_details_if_data_is_available(calendar_days_details_empty_template, current_date_state, pricing_dict, calendar_days_details, date_button_date, num_nights):
    if current_date_state == CalendarDayState.AVAILABLE:
        current_price = pricing_dict.get('price')
        pricing_dict.pop('price',None)
        calendar_days_details[date_button_date]['cleaning_fee'] = pricing_dict.get('cleaning_fee')
        pricing_dict.pop('cleaning_fee',None)
        calendar_days_details[date_button_date]['currency'] = pricing_dict.get('currency')
        pricing_dict.pop('currency',None)
        calendar_days_details[date_button_date]['extra_attributes'] = pricing_dict
        for next_day_index in range(0, num_nights):
            list_to_append = [{'check_in':date_button_date,'check_out':(date_button_date + timedelta(days=num_nights)), 'price':current_price}]
            future_day_date = date_button_date+timedelta(days=next_day_index)
            if future_day_date not in calendar_days_details:
                calendar_days_details[future_day_date] = copy.deepcopy(calendar_days_details_empty_template)
            calendar_days_details[future_day_date]['latest_prices_array'] += list_to_append
    return calendar_days_details, pricing_dict

def generate_airbnb_calendar_day_list(calendar_days_details,ROOM_ID):
    calendar_days_details_models = []
    for date, date_details  in calendar_days_details.items():
        airbnb_calendar_day = AirBnbRoomCalendarDay(room_id = ROOM_ID, 
                                                    calendar_day=date,
                                                    state=date_details['current_date_state'],
                                                    previous_state = None,
                                                    minimum_stay_nights = date_details['minimum_stay_nights'],
                                                    price = calculate_mean([i['price'] for i in date_details['latest_prices_array']]),
                                                    latest_prices_array = date_details['latest_prices_array'],
                                                    cleaning_fee = date_details['cleaning_fee'],
                                                    currency = date_details['currency'],
                                                    extra_attributes = date_details['extra_attributes'],
                                                    )
        calendar_days_details_models.append(airbnb_calendar_day)
    return calendar_days_details_models

# %%
driver = driver_setup(settings={"headless": True})
ROOM_ID = 34281543
ROOM_URL_FOR_TEST=  f"https://www.airbnb.com/rooms/{ROOM_ID}?adults=2" # "https://www.airbnb.com/rooms/634438216271572667?adults=2"
NUMBER_MONTHS_TO_CHECK = 6

logger.info("[%s] getting room", ROOM_ID)
driver.get(ROOM_URL_FOR_TEST)
logger.info("[%s] room gotten", ROOM_ID)
close_translation_popup_if_exists(driver, ROOM_ID)
logger.info("[%s] close_translation_popup_if_exists over", ROOM_ID)
close_cookie_banner_if_exists(driver, ROOM_ID)
logger.info("[%s] close_cookie_banner_if_exists over", ROOM_ID)
# open_the_calendar_form(driver) # not needed as there is a table with dates in the main page, without even clicking on the calendar popup
# Out:
# 2024-09-14 16:29:25 - INFO - __main__ - [34281543] getting room
# 2024-09-14 16:29:28 - INFO - __main__ - [34281543] room gotten
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] No 'Transaction on' form was found
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] close_translation_popup_if_exists over
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] close_cookie_banner_if_exists over

# %%
calendar_days_details_empty_template = {'current_date_state':None,'minimum_stay_nights':None,'latest_prices_array':[],'cleaning_fee':None,'currency':None,'extra_attributes':{},'price':None}
calendar_days_details = {}
old_visible_table_one_string = None
for num_nexts_to_click in range(NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK):
    old_visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables_with_retry(driver, old_visible_table_one_string,ROOM_ID, sleep_after_retry_sec=1, max_retries=3)
    logger.info("[%s] old_visible_table_one_string: %s, first_visible_table: %s, second_visible_table: %s", ROOM_ID,old_visible_table_one_string, first_visible_table,second_visible_table)
    second_visible_table_cells = None
    first_visible_table_cells = get_all_cells_from_table(first_visible_table)
    for first_table_cell_index,first_table_cell in enumerate(first_visible_table_cells):
        date_button_aria_label = first_table_cell.get_attribute("aria-label")
        date_button_date = parse_date(date_button_aria_label.split(".", 1)[0])
        current_date_state, num_nights = get_state_and_num_min_nights_of_given_date(date_button_aria_label,first_table_cell,first_visible_table,driver, ROOM_ID)
        logger.info("[%s] date_button_date: %s. current_date_state: %s. num_nights: %s.",ROOM_ID,date_button_date, current_date_state, num_nights)
        pricing_dict, second_visible_table_cells = get_smallest_stay_interval_and_pricing_dict(current_date_state,num_nights, date_button_date, second_visible_table, second_visible_table_cells, first_visible_table_cells, first_table_cell, first_table_cell_index, driver, ROOM_ID)
        calendar_days_details.setdefault(date_button_date, copy.deepcopy(calendar_days_details_empty_template))
        calendar_days_details[date_button_date]['current_date_state'] = current_date_state
        calendar_days_details[date_button_date]['minimum_stay_nights'] = num_nights
        calendar_days_details, pricing_dict = enrich_calendar_days_details_if_data_is_available(calendar_days_details_empty_template, current_date_state, pricing_dict, calendar_days_details, date_button_date, num_nights)

    if (num_nexts_to_click+1) < NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK:
        next_month(driver)
    time.sleep(1)
# Out:
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] visible table number 1 is for month September 2024
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] visible table number 2 is for month October 2024
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:29:33 - INFO - __main__ - [34281543] old_visible_table_one_string: September 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.35")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.38")>
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-01. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-02. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-03. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-04. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-05. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-06. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-07. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-08. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-09. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-10. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-11. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-12. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-13. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-14. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-15. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-16. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-17. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-18. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-19. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-20. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-21. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-22. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-23. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-24. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-25. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-26. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-27. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-28. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-29. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:34 - INFO - __main__ - [34281543] date_button_date: 2024-09-30. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] visible table number 1 is for month October 2024
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] visible table number 2 is for month November 2024
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] old_visible_table_one_string: October 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.38")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.93")>
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-01. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-02. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-03. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-04. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-05. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-06. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-07. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-08. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-09. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-10. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-11. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-12. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-13. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-14. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-15. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-16. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-17. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-18. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-19. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-20. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-21. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-22. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-23. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-24. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-25. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:35 - INFO - __main__ - [34281543] date_button_date: 2024-10-26. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-14 16:29:36 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 135, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:36 - INFO - __main__ - [34281543] date_button_date: 2024-10-27. current_date_state: AVAILABLE_NO_CHECKOUT_DATE. num_nights: 2.
# 2024-09-14 16:29:37 - INFO - __main__ - [34281543] date_button_date: 2024-10-28. current_date_state: CHECKOUT_ONLY. num_nights: None.
# 2024-09-14 16:29:37 - INFO - __main__ - [34281543] date_button_date: 2024-10-29. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:37 - INFO - __main__ - [34281543] date_button_date: 2024-10-30. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:37 - INFO - __main__ - [34281543] date_button_date: 2024-10-31. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] visible table number 1 is for month November 2024
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] visible table number 2 is for month December 2024
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] old_visible_table_one_string: November 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.93")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.147")>
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] date_button_date: 2024-11-01. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] date_button_date: 2024-11-02. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] date_button_date: 2024-11-03. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:29:38 - INFO - __main__ - [34281543] date_button_date: 2024-11-04. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:39 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:39 - INFO - __main__ - [34281543] date_button_date: 2024-11-05. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:40 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:41 - INFO - __main__ - [34281543] date_button_date: 2024-11-06. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:42 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:42 - INFO - __main__ - [34281543] date_button_date: 2024-11-07. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:43 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:43 - INFO - __main__ - [34281543] date_button_date: 2024-11-08. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:45 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:45 - INFO - __main__ - [34281543] date_button_date: 2024-11-09. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:46 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:46 - INFO - __main__ - [34281543] date_button_date: 2024-11-10. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:47 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:47 - INFO - __main__ - [34281543] date_button_date: 2024-11-11. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-14 16:29:49 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 118, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:49 - INFO - __main__ - [34281543] date_button_date: 2024-11-12. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-14 16:29:50 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 118, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:50 - INFO - __main__ - [34281543] date_button_date: 2024-11-13. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-14 16:29:51 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 118, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:52 - INFO - __main__ - [34281543] date_button_date: 2024-11-14. current_date_state: AVAILABLE. num_nights: 2.
# 2024-09-14 16:29:53 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 118, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:53 - INFO - __main__ - [34281543] date_button_date: 2024-11-15. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:54 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:54 - INFO - __main__ - [34281543] date_button_date: 2024-11-16. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:55 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:56 - INFO - __main__ - [34281543] date_button_date: 2024-11-17. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:57 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:57 - INFO - __main__ - [34281543] date_button_date: 2024-11-18. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:58 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:29:58 - INFO - __main__ - [34281543] date_button_date: 2024-11-19. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:29:59 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:00 - INFO - __main__ - [34281543] date_button_date: 2024-11-20. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:01 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:01 - INFO - __main__ - [34281543] date_button_date: 2024-11-21. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:02 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:02 - INFO - __main__ - [34281543] date_button_date: 2024-11-22. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:04 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:04 - INFO - __main__ - [34281543] date_button_date: 2024-11-23. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:05 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:05 - INFO - __main__ - [34281543] date_button_date: 2024-11-24. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:06 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:06 - INFO - __main__ - [34281543] date_button_date: 2024-11-25. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:08 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:08 - INFO - __main__ - [34281543] date_button_date: 2024-11-26. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:09 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:09 - INFO - __main__ - [34281543] date_button_date: 2024-11-27. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:10 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:11 - INFO - __main__ - [34281543] date_button_date: 2024-11-28. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:11 - INFO - __main__ - [34281543] 2024-11-28 checkout will be M+1 : 2024-12-01. new_month_checkout_date_index: 0
# 2024-09-14 16:30:11 - INFO - __main__ - [34281543] len(second_visible_table_cells): 31
# 2024-09-14 16:30:11 - INFO - __main__ - [34281543] checkout_date_button_to_click.get_attribute("aria-label"): 1, Sunday, December 2024. Available. There is a 3-night minimum stay requirement. Select as check-in date.
# 2024-09-14 16:30:12 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:12 - INFO - __main__ - [34281543] date_button_date: 2024-11-29. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:12 - INFO - __main__ - [34281543] 2024-11-29 checkout will be M+1 : 2024-12-02. new_month_checkout_date_index: 1
# 2024-09-14 16:30:12 - INFO - __main__ - [34281543] checkout_date_button_to_click.get_attribute("aria-label"): 2, Monday, December 2024. Available. There is a 3-night minimum stay requirement. Select as check-in date.
# 2024-09-14 16:30:13 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:13 - INFO - __main__ - [34281543] date_button_date: 2024-11-30. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:13 - INFO - __main__ - [34281543] 2024-11-30 checkout will be M+1 : 2024-12-03. new_month_checkout_date_index: 2
# 2024-09-14 16:30:13 - INFO - __main__ - [34281543] checkout_date_button_to_click.get_attribute("aria-label"): 3, Tuesday, December 2024. Available. There is a 3-night minimum stay requirement. Select as check-in date.
# 2024-09-14 16:30:15 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:16 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:30:16 - INFO - __main__ - [34281543] visible table number 1 is for month December 2024
# 2024-09-14 16:30:16 - INFO - __main__ - [34281543] visible table number 2 is for month January 2025
# 2024-09-14 16:30:16 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:30:16 - INFO - __main__ - [34281543] old_visible_table_one_string: December 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.147")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.322")>
# 2024-09-14 16:30:16 - INFO - __main__ - [34281543] date_button_date: 2024-12-01. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:17 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:17 - INFO - __main__ - [34281543] date_button_date: 2024-12-02. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:19 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:19 - INFO - __main__ - [34281543] date_button_date: 2024-12-03. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:20 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 117, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:20 - INFO - __main__ - [34281543] date_button_date: 2024-12-04. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:21 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 129, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:21 - INFO - __main__ - [34281543] date_button_date: 2024-12-05. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:23 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 140, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:23 - INFO - __main__ - [34281543] date_button_date: 2024-12-06. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:24 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 151, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:24 - INFO - __main__ - [34281543] date_button_date: 2024-12-07. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:25 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 140, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:26 - INFO - __main__ - [34281543] date_button_date: 2024-12-08. current_date_state: AVAILABLE. num_nights: 3.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] pricing_parsed_elements: [{'description': 'night_price', 'amount': 129, 'currency': '£', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 59, 'currency': '£', 'extra': ''}]
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-09. current_date_state: AVAILABLE_NO_CHECKOUT_DATE. num_nights: 3.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-10. current_date_state: AVAILABLE_NO_CHECKOUT_DATE. num_nights: 3.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-11. current_date_state: CHECKOUT_ONLY. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-12. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-13. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-14. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-15. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-16. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-17. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-18. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-19. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-20. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-21. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-22. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-23. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-24. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-25. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-26. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-27. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-28. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-29. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-30. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:27 - INFO - __main__ - [34281543] date_button_date: 2024-12-31. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] visible table number 1 is for month January 2025
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] visible table number 2 is for month February 2025
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] old_visible_table_one_string: January 2025, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.322")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.350")>
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-01. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-02. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-03. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-04. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-05. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-06. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-07. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-08. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-09. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-10. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-11. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-12. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-13. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-14. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-15. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-16. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-17. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-18. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-19. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-20. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-21. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-22. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-23. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-24. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-25. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-26. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-27. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-28. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-29. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-30. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:28 - INFO - __main__ - [34281543] date_button_date: 2025-01-31. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] visible table number 1 is for month February 2025
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] visible table number 2 is for month March 2025
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] table is not visible. Will will go to next one
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] old_visible_table_one_string: February 2025, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.350")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="2c87a4e42c37a60a2f4011443145a9ec", element="f.091AD4D0DE4A6EE120CD0200F577A274.d.6CF64A7302514BEA31E7B871C19C5DD8.e.400")>
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-01. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-02. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-03. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-04. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-05. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-06. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-07. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-08. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-09. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-10. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-11. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-12. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-13. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-14. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-15. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-16. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-17. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-18. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-19. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-20. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-21. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-22. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-23. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-24. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-25. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-26. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-27. current_date_state: UNAVAILABLE. num_nights: None.
# 2024-09-14 16:30:29 - INFO - __main__ - [34281543] date_button_date: 2025-02-28. current_date_state: UNAVAILABLE. num_nights: None.

# %%
calendar_days_details_models = generate_airbnb_calendar_day_list(calendar_days_details,ROOM_ID)

# %%
[ i for i in calendar_days_details_models if i.currency][0].price
# Out:
# 135.0
