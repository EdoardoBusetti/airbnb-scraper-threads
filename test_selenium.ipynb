# %%
import time
import math
import copy
import pandas as pd
from datetime import datetime, timedelta
from models import CalendarDayState, AirBnbRoomCalendarDay
import logging

from my_webdriver import driver_setup

MAX_WAIT_FOR_TRANSLATION_ON_POPUP_SEC = 5
MAX_WAIT_FOR_COOKIES_POPUP_SEC = 5
NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK = 6
MONTHS_PRESENT_IN_ONE_ELEMENT = 4
TIME_SLEEP_AFTER_CAL_NEXT_CLICK_SEC = 0.2
NUMBER_CAL_FETCHES_NEEDED = math.ceil(
    NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK / MONTHS_PRESENT_IN_ONE_ELEMENT
)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(name)s - %(message)s', 
    datefmt='%Y-%m-%d %H:%M:%S',  # Customize the time format (optional)
    force=True,
)
logger = logging.getLogger(__name__)


from  selenium_airbnb_calendar_scraper import close_translation_popup_if_exists,close_cookie_banner_if_exists,parse_date,get_calendar_table_from_driver,is_day_disabled,clear_dates,get_two_visible_tables,parse_from_day_button_aria_label_to_state, first_day_of_month,get_all_cells_from_table, parse_pricing_from_pricing_form,  from_pricing_elements_to_pricing_dict, calculate_mean, get_two_visible_tables_with_retry, next_month, get_state_and_num_min_nights_of_given_date, get_smallest_stay_interval_and_pricing_dict, enrich_calendar_days_details_if_data_is_available, generate_airbnb_calendar_day_list

# %%
driver = driver_setup(settings={"headless": False})
ROOM_ID = 14132224
ROOM_URL_FOR_TEST=  f"https://www.airbnb.com/rooms/{ROOM_ID}?adults=2" # "https://www.airbnb.com/rooms/634438216271572667?adults=2"
NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK = 6

logger.info("[%s] getting room", ROOM_ID)
driver.get(ROOM_URL_FOR_TEST)
logger.info("[%s] room gotten", ROOM_ID)
close_translation_popup_if_exists(driver, ROOM_ID)
logger.info("[%s] close_translation_popup_if_exists over", ROOM_ID)
close_cookie_banner_if_exists(driver, ROOM_ID)
logger.info("[%s] close_cookie_banner_if_exists over", ROOM_ID)


calendar_days_details_empty_template = {'current_date_state':None,'minimum_stay_nights':None,'latest_prices_array':[],'cleaning_fee':None,'currency':None,'extra_attributes':{},'price':None}
calendar_days_details = {}
old_visible_table_one_string = None
for num_nexts_to_click in range(NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK):
    old_visible_table_one_string, first_visible_table, second_visible_table = get_two_visible_tables_with_retry(driver, old_visible_table_one_string,ROOM_ID, sleep_after_retry_sec=1, max_retries=3)
    logger.info("[%s] old_visible_table_one_string: %s, first_visible_table: %s, second_visible_table: %s", ROOM_ID,old_visible_table_one_string, first_visible_table,second_visible_table)
    second_visible_table_cells = None
    first_visible_table_cells = get_all_cells_from_table(first_visible_table)
    for first_table_cell_index,first_table_cell in enumerate(first_visible_table_cells):
        date_button_aria_label = first_table_cell.get_attribute("aria-label")
        date_button_date = parse_date(date_button_aria_label.split(".", 1)[0])
        # time.sleep(10000000)
        current_date_state, num_nights = get_state_and_num_min_nights_of_given_date(date_button_aria_label,first_table_cell,first_visible_table,driver, ROOM_ID)
        logger.info("[%s] date_button_date: %s. current_date_state: %s. num_nights: %s.",ROOM_ID,date_button_date, current_date_state, num_nights)
        pricing_dict, second_visible_table_cells = get_smallest_stay_interval_and_pricing_dict(current_date_state,num_nights, date_button_date, second_visible_table, second_visible_table_cells, first_visible_table_cells, first_table_cell, first_table_cell_index, driver, ROOM_ID)
        calendar_days_details.setdefault(date_button_date, copy.deepcopy(calendar_days_details_empty_template))
        calendar_days_details[date_button_date]['current_date_state'] = current_date_state
        calendar_days_details[date_button_date]['minimum_stay_nights'] = num_nights
        calendar_days_details, pricing_dict = enrich_calendar_days_details_if_data_is_available(calendar_days_details_empty_template, current_date_state, pricing_dict, calendar_days_details, date_button_date, num_nights)

    if (num_nexts_to_click+1) < NUMBER_ON_MONTHS_IN_FUTURE_TO_CHECK:
        next_month(driver)
    time.sleep(1)
# Out:
# 2024-11-14 22:05:19 - INFO - __main__ - [14132224] getting room
# 2024-11-14 22:05:21 - INFO - __main__ - [14132224] room gotten
# 2024-11-14 22:05:24 - INFO - __main__ - [14132224] close_translation_popup_if_exists over
# 2024-11-14 22:05:29 - INFO - selenium_airbnb_calendar_scraper - [14132224] No 'cookies banner' form was found
# 2024-11-14 22:05:29 - INFO - __main__ - [14132224] close_cookie_banner_if_exists over
# 2024-11-14 22:05:29 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-11-14 22:05:29 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 1 is for month November 2024
# 2024-11-14 22:05:29 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 2 is for month December 2024
# 2024-11-14 22:05:29 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-11-14 22:05:29 - INFO - __main__ - [14132224] old_visible_table_one_string: November 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="3860a0bea3b4268a426778e64e70d5bd", element="f.700FF20759A7D3E20E238AFE2F2F6D68.d.2EE8860A80D52A02367B2AE964288EC8.e.36")>, second_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="3860a0bea3b4268a426778e64e70d5bd", element="f.700FF20759A7D3E20E238AFE2F2F6D68.d.2EE8860A80D52A02367B2AE964288EC8.e.39")>
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-01. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-02. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-03. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-04. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-05. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-06. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-07. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-08. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-09. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-10. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-11. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-12. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-13. current_date_state: UNAVAILABLE_DUE_TO_PAST_DATE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-14. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-15. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:05:31 - INFO - __main__ - [14132224] date_button_date: 2024-11-16. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:05:32 - INFO - __main__ - [14132224] date_button_date: 2024-11-17. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:05:32 - INFO - __main__ - [14132224] date_button_date: 2024-11-18. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:05:32 - INFO - __main__ - [14132224] date_button_date: 2024-11-19. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:34 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:34 - INFO - __main__ - [14132224] date_button_date: 2024-11-20. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:35 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:35 - INFO - __main__ - [14132224] date_button_date: 2024-11-21. current_date_state: AVAILABLE_NO_CHECKOUT_DATE. num_nights: 2.
# 2024-11-14 22:05:35 - INFO - __main__ - [14132224] date_button_date: 2024-11-22. current_date_state: CHECKOUT_ONLY. num_nights: 1.
# 2024-11-14 22:05:35 - INFO - __main__ - [14132224] date_button_date: 2024-11-23. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:05:36 - INFO - __main__ - [14132224] date_button_date: 2024-11-24. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:37 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:38 - INFO - __main__ - [14132224] date_button_date: 2024-11-25. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:39 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:40 - INFO - __main__ - [14132224] date_button_date: 2024-11-26. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:41 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:42 - INFO - __main__ - [14132224] date_button_date: 2024-11-27. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:43 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:44 - INFO - __main__ - [14132224] date_button_date: 2024-11-28. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:45 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:45 - INFO - __main__ - [14132224] date_button_date: 2024-11-29. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:45 - INFO - selenium_airbnb_calendar_scraper - [14132224] 2024-11-29 checkout will be M+1 : 2024-12-01. new_month_checkout_date_index: 0
# 2024-11-14 22:05:47 - INFO - selenium_airbnb_calendar_scraper - [14132224] len(second_visible_table_cells): 31
# 2024-11-14 22:05:47 - INFO - selenium_airbnb_calendar_scraper - [14132224] checkout_date_button_to_click.get_attribute("aria-label"): 1, Sunday, December 2024. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# 2024-11-14 22:05:48 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:49 - INFO - __main__ - [14132224] date_button_date: 2024-11-30. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:05:49 - INFO - selenium_airbnb_calendar_scraper - [14132224] 2024-11-30 checkout will be M+1 : 2024-12-02. new_month_checkout_date_index: 1
# 2024-11-14 22:05:49 - INFO - selenium_airbnb_calendar_scraper - [14132224] checkout_date_button_to_click.get_attribute("aria-label"): 2, Monday, December 2024. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# 2024-11-14 22:05:51 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 90, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 36, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:05:52 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-11-14 22:05:52 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 1 is for month December 2024
# 2024-11-14 22:05:52 - INFO - selenium_airbnb_calendar_scraper - [14132224] visible table number 2 is for month January 2025
# 2024-11-14 22:05:52 - INFO - selenium_airbnb_calendar_scraper - [14132224] table is not visible. Will will go to next one
# 2024-11-14 22:05:52 - INFO - __main__ - [14132224] old_visible_table_one_string: December 2024, first_visible_table: <selenium.webdriver.remote.webelement.WebElement (session="3860a0bea3b4268a426778e64e70d5bd", element="f.700FF20759A7D3E20E238AFE2F2F6D68.d.2EE8860A80D52A02367B2AE964288EC8.e
current_date_state: AVAILABLE_NO_CHECKOUT_DATE. num_nights: 2.
# 2024-11-14 22:07:59 - INFO - __main__ - [14132224] date_button_date: 2025-04-11. current_date_state: CHECKOUT_ONLY. num_nights: 1.
# 2024-11-14 22:07:59 - INFO - __main__ - [14132224] date_button_date: 2025-04-12. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:07:59 - INFO - __main__ - [14132224] date_button_date: 2025-04-13. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:07:59 - INFO - __main__ - [14132224] date_button_date: 2025-04-14. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:07:59 - INFO - __main__ - [14132224] date_button_date: 2025-04-15. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:07:59 - INFO - __main__ - [14132224] date_button_date: 2025-04-16. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:00 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:01 - INFO - __main__ - [14132224] date_button_date: 2025-04-17. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:02 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:03 - INFO - __main__ - [14132224] date_button_date: 2025-04-18. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:04 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:04 - INFO - __main__ - [14132224] date_button_date: 2025-04-19. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:05 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:06 - INFO - __main__ - [14132224] date_button_date: 2025-04-20. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:08 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:08 - INFO - __main__ - [14132224] date_button_date: 2025-04-21. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:09 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:10 - INFO - __main__ - [14132224] date_button_date: 2025-04-22. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:13 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 95, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 38, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:14 - INFO - __main__ - [14132224] date_button_date: 2025-04-23. current_date_state: AVAILABLE_NO_CHECKOUT_DATE. num_nights: 2.
# 2024-11-14 22:08:14 - INFO - __main__ - [14132224] date_button_date: 2025-04-24. current_date_state: CHECKOUT_ONLY. num_nights: 1.
# 2024-11-14 22:08:14 - INFO - __main__ - [14132224] date_button_date: 2025-04-25. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:08:14 - INFO - __main__ - [14132224] date_button_date: 2025-04-26. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:08:14 - INFO - __main__ - [14132224] date_button_date: 2025-04-27. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:08:14 - INFO - __main__ - [14132224] date_button_date: 2025-04-28. current_date_state: UNAVAILABLE. num_nights: 1.
# 2024-11-14 22:08:14 - INFO - __main__ - [14132224] date_button_date: 2025-04-29. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:14 - INFO - selenium_airbnb_calendar_scraper - [14132224] 2025-04-29 checkout will be M+1 : 2025-05-01. new_month_checkout_date_index: 0
# 2024-11-14 22:08:14 - INFO - selenium_airbnb_calendar_scraper - [14132224] len(second_visible_table_cells): 31
# 2024-11-14 22:08:14 - INFO - selenium_airbnb_calendar_scraper - [14132224] checkout_date_button_to_click.get_attribute("aria-label"): 1, Thursday, May 2025. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# 2024-11-14 22:08:15 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 115, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 45, 'currency': '€', 'extra': ''}]
# 2024-11-14 22:08:16 - INFO - __main__ - [14132224] date_button_date: 2025-04-30. current_date_state: AVAILABLE. num_nights: 2.
# 2024-11-14 22:08:16 - INFO - selenium_airbnb_calendar_scraper - [14132224] 2025-04-30 checkout will be M+1 : 2025-05-02. new_month_checkout_date_index: 1
# 2024-11-14 22:08:16 - INFO - selenium_airbnb_calendar_scraper - [14132224] checkout_date_button_to_click.get_attribute("aria-label"): 2, Friday, May 2025. Available. There is a 2 night minimum stay requirement. Select as check-in date.
# 2024-11-14 22:08:17 - INFO - selenium_airbnb_calendar_scraper - [14132224] pricing_parsed_elements: [{'description': 'night_price', 'amount': 115, 'currency': '€', 'extra': ''}, {'description': 'cleaning_fee', 'amount': 30, 'currency': '€', 'extra': ''}, {'description': 'airbnb_service_fee', 'amount': 45, 'currency': '€', 'extra': ''}]

# %%
calendar_days_details_models = generate_airbnb_calendar_day_list(calendar_days_details,ROOM_ID)

# %%
from models import Base, db_url, save_or_update_airbnb_date
import sqlalchemy
from sqlalchemy.orm import Session
engine = sqlalchemy.create_engine(
    db_url, echo=False
)  # We have also specified a parameter create_engine.echo, which will instruct the Engine to log all of the SQL it emits to a Python logger that will write to standard out.
Base.metadata.create_all(engine)

session = Session(engine)
for calendar_days_details in calendar_days_details_models:
    save_or_update_airbnb_date(session=session, new_instance=i)
    
session.commit()

# %%
calendar_days_details

# %%
len(calendar_days_details_models)
# Out:
# 182
